# %%
#Implementation of Gradient Descent using tensorflow
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras

# %%
df=pd.read_csv("insurance_data.csv")
df.head()
# Out:
#    age  affordibility  bought_insurance
# 0   22              1                 0
# 1   25              0                 0
# 2   47              1                 1
# 3   52              0                 0
# 4   46              1                 1

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(df[['age','affordibility']],df.bought_insurance,test_size=0.2,random_state=25)

# %% [raw]
# #scaling for better accuracy and less error rate
# X_train_scaled=X_train.copy()
# X_train_scaled['age']=X_train_scaled['age']/100
#
# X_test_scaled=X_test.copy()
# X_test_scaled['age']=X_test_scaled['age']/100

# %%
model=keras.Sequential([
    keras.layers.Dense(1,input_shape=(2,),activation='sigmoid',kernel_initializer='ones',bias_initializer='zeros')
])
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy'])
model.fit(X_train_scaled,y_train,epochs=5000)
# Out:
# Epoch 1/5000
# E0000 00:00:1772966634.359798    7088 cuda_platform.cc:52] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 532ms/step - accuracy: 0.5000 - loss: 0.7113
# Epoch 2/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5000 - loss: 0.7110
# Epoch 3/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5000 - loss: 0.7106
# Epoch 4/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.5000 - loss: 0.7102
# Epoch 5/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5000 - loss: 0.7098
# Epoch 6/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.5000 - loss: 0.7094
# Epoch 7/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.5000 - loss: 0.7091
# Epoch 8/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.5000 - loss: 0.7087
# Epoch 9/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.5000 - loss: 0.7083
# Epoch 10/5000
# ...

# %% [markdown]
# model.evaluate(X_test_scaled,y_test)

# %%
model.evaluate(X_test_scaled,y_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.3550
# [0.35497763752937317, 1.0]

# %%
y_test
# Out:
# 2     1
# 10    0
# 21    0
# 11    0
# 14    1
# 9     1
# Name: bought_insurance, dtype: int64

# %%
coef, intercept=model.get_weights()

# %%
coef, intercept
# Out:
# (array([[5.0608625],
#         [1.408652 ]], dtype=float32),
#  array([-2.9137027], dtype=float32))

# %% [raw]
# here w1=5.0608 and w2=1.4086 and bias=-2.913

# %% [raw]
# Implementation of Gradient DEscent without uisng tensorflow keras

# %%
def sigmoid(x):
    import math
    return 1/(1+math.exp(-x))
sigmoid(18)
# Out:
# 0.9999999847700205

# %%
X_test
# Out:
#     age  affordibility
# 2    47              1
# 10   18              1
# 21   26              0
# 11   28              1
# 14   49              1
# 9    61              1

# %%
def prediction_function(age,affordibility):
    weighted_sum=coef[0]*age+coef[1]*affordibility+intercept
    return sigmoid(weighted_sum)
prediction_function(.47,1)
# Out:
# /tmp/ipykernel_7088/574919516.py:3: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   return 1/(1+math.exp(-x))
# 0.7054847702382996

# %%
def sigmoid_numpy(X):
    return 1/(1+np.exp(-X))
sigmoid_numpy(np.array([12,0,1]))
# Out:
# array([0.99999386, 0.5       , 0.73105858])

# %%
def log_loss(y_true,y_predicted):
    epsilon=1e-15
    y_predicted_new=[max(i,epsilon) for i in y_predicted]
    y_predicted_new=[min(i,1-epsilon) for i in y_predicted_new]
    y_predicted_new=np.array(y_predicted_new)
    return -np.mean(y_true*np.log(y_predicted_new)+(1-y_true)*np.log(1-y_predicted_new))

# %%
def gradient_descent(age,affordibility,y_true,epochs,loss_threshold):
    w1=w2=0
    bias=0
    rate=0.5
    n=len(age)
    for i in range(epochs):
        weighted_sum=w1*age+w2*affordibility+bias
        y_predicted=sigmoid_numpy(weighted_sum)
        loss=log_loss(y_true,y_predicted)

        w1d=(1/n)*np.dot(np.transpose(age),(y_predicted-y_true))
        w2d=(1/n)*np.dot(np.transpose(affordibility),(y_predicted-y_true))

        bias_d=np.mean(y_predicted-y_true)
        w1=w1-rate*w1d
        w2=w2-rate*w2d
        bias=bias-rate*bias_d

        print(f'Epoch:{i},w1:{w1},w2:{w2},bias:{bias},loss:{loss}')

        if loss<=loss_threshold:
            break
    return w1,w2,bias

# %%
gradient_descent(X_train_scaled['age'],X_train_scaled['affordibility'],y_train,1000,0.4631)
# Out:
# Epoch:0,w1:0.024318181818181826,w2:0.045454545454545456,bias:0.0,loss:0.6931471805599453
# Epoch:1,w1:0.046532101759595226,w2:0.08647105225023963,bias:-0.004841495282008105,loss:0.6880851350148476
# Epoch:2,w1:0.06708738929577727,w2:0.123863596911539,bias:-0.013455423643272062,loss:0.6838539043604727
# Epoch:3,w1:0.08633804668084633,w2:0.1582818726587562,bias:-0.024993103907863065,loss:0.6801769512884495
# Epoch:4,w1:0.10456450468395169,w2:0.19024321720378462,bias:-0.03878266341920814,loss:0.6768786343273759
# Epoch:5,w1:0.12198861288216892,w2:0.22015943486833162,bias:-0.05429295760984407,loss:0.673847150675346
# Epoch:6,w1:0.13878577300913103,w2:0.24835860186955866,bias:-0.07110440662581538,loss:0.6710109783986781
# Epoch:7,w1:0.15509462872883883,w2:0.2751025150492992,bias:-0.08888572163473854,loss:0.6683239981162274
# Epoch:8,w1:0.17102475084873503,w2:0.3006005395908055,bias:-0.10737545129278292,loss:0.665756123870844
# ...

# %%
coef,intercept
# Out:
# (array([[5.0608625],
#         [1.408652 ]], dtype=float32),
#  array([-2.9137027], dtype=float32))
